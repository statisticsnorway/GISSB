# %%
# Velger antall adresser #
antall_adresser <- 100 # OK
# antall_adresser <- 1000 # OK
# antall_adresser <- 10000 # kernel dør med min, medium, fungerer med max

# %%
suppressPackageStartupMessages({
library(tidyverse)
})

source("/home/jovyan/GISSB/R/address_to_coords.R")
source("/home/jovyan/GISSB/R/coords_to_google.R")
source("/home/jovyan/GISSB/R/coords_to_node.R")
source("/home/jovyan/GISSB/R/path_leaflet.R")
source("/home/jovyan/GISSB/R/shortest_path_cppRouting.R")
source("/home/jovyan/GISSB/R/shortest_path_igraph.R")

# source("/home/jovyan/GISSB/experimental/vegnett_to_R (TR).R")
# source("/home/jovyan/GISSB/experimental/coords_to_node.R")
# source("/home/jovyan/GISSB/experimental/shortest_path_cppRouting.R")
source("/home/jovyan/GISSB/experimental/problem_coords_fix.R")

source("/home/jovyan/fellesr/R/DAPLA_funcs.R")

# %% [markdown]
# # 2021 vs. 2022

# %%
resultater_100_tilfeldige_adresser_2021 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2021_resultater_tilfeldige_adresser_100.parquet") %>%
dplyr::rename(minutes_2021 = minutes)

resultater_100_tilfeldige_adresser_2022 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2022_resultater_tilfeldige_adresser_100.parquet") %>%
dplyr::rename(minutes_2022 = minutes)

resultater_100_tilfeldige_adresser <- left_join(resultater_100_tilfeldige_adresser_2021, resultater_100_tilfeldige_adresser_2022, by = c("idx", "idx_to")) %>%
dplyr::mutate(diff = minutes_2021-minutes_2022)

# head(resultater_100_tilfeldige_adresser_2021)
# head(resultater_100_tilfeldige_adresser_2022)

resultater_100_tilfeldige_adresser %>%
dplyr::arrange(desc(diff))

# %%
resultater_1000_tilfeldige_adresser_2021 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2021_resultater_tilfeldige_adresser_1000.parquet") %>%
dplyr::rename(minutes_2021 = minutes)

resultater_1000_tilfeldige_adresser_2022 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2022_resultater_tilfeldige_adresser_1000.parquet") %>%
dplyr::rename(minutes_2022 = minutes)

head(resultater_1000_tilfeldige_adresser_2021)
head(resultater_1000_tilfeldige_adresser_2022)

# %% [markdown]
# # Sperring test

# %%
list.files("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/")
# Out:
#  [1] "2019_resultater_tilfeldige_adresser_100.parquet"
#  [2] "2019_resultater_tilfeldige_adresser_1000.parquet"
#  [3] "2019_resultater_tilfeldige_adresser_10000.parquet"
#  [4] "2020_resultater_tilfeldige_adresser_100.parquet"
#  [5] "2020_resultater_tilfeldige_adresser_1000.parquet"
#  [6] "2020_resultater_tilfeldige_adresser_10000.parquet"
#  [7] "2021_resultater_tilfeldige_adresser_100.parquet"
#  [8] "2021_resultater_tilfeldige_adresser_1000.parquet"
#  [9] "2021_resultater_tilfeldige_adresser_10000.parquet"
# [10] "2021_resultater_tilfeldige_adresser_1000_TR.parquet"
# [11] "2021_resultater_tilfeldige_adresser_100_SPERRING.parquet"
# [12] "2021_resultater_tilfeldige_adresser_100_TR.parquet"
# [13] "2022_resultater_tilfeldige_adresser_100.parquet"
# [14] "2022_resultater_tilfeldige_adresser_1000.parquet"
# [15] "2022_resultater_tilfeldige_adresser_10000.parquet"

# %%
# gcs_delete_object("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2021_resultater_tilfeldige_adresser_100_SPERRING.parquet")

# %%
resultater_100_tilfeldige_adresser_2021 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2021_resultater_tilfeldige_adresser_100.parquet") %>%
dplyr::rename(minutes_2021 = minutes)

resultater_100_tilfeldige_adresser_2021_SPERRING <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2021_resultater_tilfeldige_adresser_100_SPERRING.parquet") %>%
dplyr::rename(minutes_2021_SPERRING = minutes)

resultater_100_tilfeldige_adresser <- dplyr::left_join(resultater_100_tilfeldige_adresser_2021, resultater_100_tilfeldige_adresser_2021_SPERRING, by = c("idx", "idx_to")) %>%
dplyr::mutate(diff = minutes_2021-minutes_2021_SPERRING)

# %%
resultater_100_tilfeldige_adresser %>%
dplyr::arrange(desc(diff))
# Out:
#      idx idx_to minutes_2021 minutes_2021_SPERRING diff
# 1    74  56     10.714514     7.086503             3.628011
# 2    31   5     11.860231     8.471726             3.388504
# 3     5  31     12.339999     9.034587             3.305412
# 4    56  74     10.173689     7.105741             3.067948
# 5    74  99     18.169167    15.104164             3.065003
# 6    99  74     18.553415    15.511004             3.042411
# 7    13  99     26.823002    23.789244             3.033758
# 8    99  13     25.992164    23.096064             2.896100
# 9    70  74     16.280396    13.460400             2.819995
# 10    2  99     28.119075    25.316784             2.802290
# 11   81  74      8.551915     5.818785             2.733130
# 12   99   2     27.288237    24.623604             2.664632
# 13   74  70     16.249770    13.805305             2.444465
# 14    5   6     14.167416    11.874519             2.292897
# 15   79  13     24.918391    22.785870             2.132521
# ...
