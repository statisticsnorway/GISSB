# %%
# Velger antall adresser #
antall_adresser <- 100 # OK
# antall_adresser <- 1000 # OK
# antall_adresser <- 10000 # kernel dør med min, medium, fungerer med max

# %%
suppressPackageStartupMessages({
library(tidyverse)
})

source("/home/jovyan/GISSB/R/address_to_coords.R")
source("/home/jovyan/GISSB/R/coords_to_google.R")
source("/home/jovyan/GISSB/R/coords_to_node.R")
source("/home/jovyan/GISSB/R/path_leaflet.R")
source("/home/jovyan/GISSB/R/shortest_path_cppRouting.R")
source("/home/jovyan/GISSB/R/shortest_path_igraph.R")

source("/home/jovyan/GISSB/experimental/vegnett_to_R (TR).R")
source("/home/jovyan/GISSB/experimental/coords_to_node.R")
source("/home/jovyan/GISSB/experimental/shortest_path_cppRouting.R")
source("/home/jovyan/GISSB/experimental/problem_coords_fix.R")

source("/home/jovyan/fellesr/R/DAPLA_funcs.R")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”

# %%
resultater_100_tilfeldige_adresser_2021 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2021_resultater_tilfeldige_adresser_100.parquet") %>%
dplyr::rename(minutes_2021 = minutes)

resultater_100_tilfeldige_adresser_2022 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2022_resultater_tilfeldige_adresser_100.parquet") %>%
dplyr::rename(minutes_2022 = minutes)

resultater_100_tilfeldige_adresser <- left_join(resultater_100_tilfeldige_adresser_2021, resultater_100_tilfeldige_adresser_2022, by = c("idx", "idx_to")) %>%
dplyr::mutate(diff = minutes_2021-minutes_2022)

# head(resultater_100_tilfeldige_adresser_2021)
# head(resultater_100_tilfeldige_adresser_2022)

resultater_100_tilfeldige_adresser %>%
dplyr::arrange(desc(diff))
# Out:
#      idx idx_to minutes_2021 minutes_2022 diff
# 1    92  13     29.60278     21.627931    7.974847
# 2    87  13     15.77298      8.157587    7.615389
# 3    13  92     29.05625     21.637078    7.419168
# 4    13  78     29.75583     23.372577    6.383257
# 5    78  13     29.66670     23.363431    6.303268
# 6    81  13     17.26790     11.206111    6.061788
# 7    22  13     24.86129     19.222887    5.638407
# 8    64  13     25.96966     20.346172    5.623490
# 9    44  13     24.24103     18.627557    5.613477
# 10   39  13     20.31719     14.746451    5.570740
# 11   79  13     22.29805     16.750377    5.547676
# 12   51  13     24.61318     19.077605    5.535573
# 13   92   2     31.12329     25.593968    5.529323
# 14   13  76     23.02959     17.506293    5.523298
# 15   33  13     22.38807     16.866891    5.521175
# 16   95  13     24.58815     19.075744    5.512411
# 17    6  13     17.96057     12.448209    5.512365
# 18   63  13     25.65159     20.142829    5.508761
# 19   37  13     26.92007     21.412273    5.507795
# 20   72  13     22.97299     17.468475    5.504514
# 21   28  13     22.65376     17.149631    5.504132
# 22    9  13     23.45654     17.952759    5.503780
# 23   21  13     25.28975     19.786468    5.503279
# 24   35  13     30.01428     24.511283    5.503001
# 25   12  13     21.90083     16.397903    5.502924
# 26   41  13     21.48160     15.978890    5.502708
# 27   69  13     22.11293     16.610223    5.502708
# 28   53  13     25.67274     20.170424    5.502312
# 29    7  13     21.27558     15.773439    5.502139
# 30   65  13     24.94792     19.446050    5.501869
# ⋮    ⋮   ⋮      ⋮            ⋮            ⋮
# 9871 94   30    38.555944    39.949970    -1.394026
# 9872 94   80    38.664664    40.059356    -1.394692
# 9873 94   55    35.992536    37.388233    -1.395697
# 9874 94   16    34.862565    36.258557    -1.395991
# 9875 94    1    35.772877    37.168892    -1.396015
# 9876 94   52    35.337435    36.733658    -1.396224
# 9877 94   87    33.789114    35.185362    -1.396248
# 9878 94   18    35.151359    36.547937    -1.396578
# 9879 94   29    34.928053    36.324737    -1.396685
# 9880 94   57    34.663702    36.060438    -1.396736
# 9881 94   61    37.505522    38.902273    -1.396751
# 9882 94   96    33.868246    35.265179    -1.396932
# 9883 94   23    32.364101    33.761162    -1.397062
# 9884 94   42    35.936465    37.333685    -1.397221
# 9885 94  100    33.958450    35.355834    -1.397384
# 9886 94   53    27.439302    28.837481    -1.398179
# 9887 75   94    28.824435    30.239006    -1.414570
# 9888 94   75    28.923352    30.349054    -1.425702
# 9889 80   49     6.436135     7.880857    -1.444722
# 9890 11   94    33.073813    34.541258    -1.467445
# 9891 49   80     6.410903     7.920762    -1.509858
# 9892 94    8    39.665136    41.314271    -1.649135
# 9893 94    4    19.600565    21.327371    -1.726806
# 9894 94   11    32.744544    34.492276    -1.747732
# 9895 94   45    19.143473    20.972095    -1.828623
# 9896 45   94    19.752815    21.582290    -1.829474
# 9897 94   37    20.257900    22.121340    -1.863440
# 9898 59   94    23.051429    24.998820    -1.947392
# 9899 67   80     6.078514     9.027831    -2.949318
# 9900 80   67     6.103065     9.095975    -2.992910

# %%
resultater_1000_tilfeldige_adresser_2021 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2021_resultater_tilfeldige_adresser_1000.parquet") %>%
dplyr::rename(minutes_2021 = minutes)

resultater_1000_tilfeldige_adresser_2022 <- read_SSB("ssb-prod-dapla-felles-data-delt/GIS/Vegnett_benchmark/Resultater_Sindre/2022_resultater_tilfeldige_adresser_1000.parquet") %>%
dplyr::rename(minutes_2022 = minutes)

head(resultater_1000_tilfeldige_adresser_2021)
head(resultater_1000_tilfeldige_adresser_2022)
# Out:
#   idx idx_to minutes_2021
# 1 3   2       5.047693
# 2 4   2      20.128377
# 3 5   2       2.710498
# 4 6   2      24.046562
# 5 7   2      12.513118
# 6 8   2      16.570761
#   idx idx_to minutes_2022
# 1 3   2       5.043611
# 2 4   2      20.303704
# 3 5   2       2.708688
# 4 6   2      24.037115
# 5 7   2      12.504234
# 6 8   2      16.563740
